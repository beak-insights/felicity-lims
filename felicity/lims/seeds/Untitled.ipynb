# %%
import pandas as pd
import numpy as np

# %%
clinical_breakpoints = pd.read_csv(f"./data/amr-r/clinical_breakpoints.txt", delimiter="\t")
clinical_breakpoints.head(20)
# Out:
#       guideline   type   host method                                   site  \
# 0   EUCAST 2024  human  human   DISK                                    NaN
# 1   EUCAST 2024  human  human    MIC                                    NaN
# 2   EUCAST 2024  human  human   DISK                                    NaN
# 3   EUCAST 2024  human  human    MIC                                    NaN
# 4   EUCAST 2024  human  human   DISK                                    NaN
# 5   EUCAST 2024  human  human    MIC                                    NaN
# 6   EUCAST 2024  human  human   DISK                                    NaN
# 7   EUCAST 2024  human  human   DISK  Uncomplicated urinary tract infection
# 8   EUCAST 2024  human  human    MIC                                    NaN
# 9   EUCAST 2024  human  human    MIC  Uncomplicated urinary tract infection
# 10  EUCAST 2024  human  human   DISK                                    NaN
# ...

# %%
antivirals = pd.read_csv(f"./data/amr-r/antivirals.txt", delimiter="\t")
antivirals.head(2)
# Out:
#     av       name      atc          cid  \
# 0  ABA   Abacavir  J05AF06     441300.0
# 1  ACI  Aciclovir  J05AB01  135398513.0
#
#                                            atc_group  \
# 0  Nucleoside and nucleotide reverse transcriptas...
# 1  Nucleosides and nucleotides excl. reverse tran...
#
#                                             synonyms  oral_ddd oral_units  \
# 0                   abacavir sulfate,avacavir,ziagen       0.6          g
# 1  acicloftal,aciclovier,aciclovirum,activir,acyc...       4.0          g
#
#    iv_ddd iv_units                                              loinc
# 0     NaN      NaN  29113-8,30273-7,30287-7,30303-2,78772-1,78773-...
# 1     4.0        g                                                NaN

# %%
antibiotics = pd.read_csv(f"./data/amr-r/antibiotics.txt", delimiter="\t")
antibiotics.head(2)
# Out:
#     ab        cid                   name                    group      atc  \
# 0  AMA     4649.0  4-aminosalicylic acid       Antimycobacterials  J04AA01
# 1  ACM  6450012.0      Acetylmidecamycin  Macrolides/lincosamides      NaN
#
#                             atc_group1                           atc_group2  \
# 0  Drugs for treatment of tuberculosis  Aminosalicylic acid and derivatives
# 1                                  NaN                                  NaN
#
#   abbreviations                                           synonyms  oral_ddd  \
# 0           NaN  aminopar,aminosalicylic,aminosalicylicacid,ami...      12.0
# 1           NaN                                                NaN       NaN
#
#   oral_units  iv_ddd iv_units loinc
# 0          g     NaN      NaN   NaN
# 1        NaN     NaN      NaN   NaN

# %%
dosage = pd.read_csv(f"./data/amr-r/dosage.txt", delimiter="\t")
dosage.head(2)
# Out:
#     ab         name             type         dose  dose_times administration  \
# 0  AMK     Amikacin  standard_dosage  25-30 mg/kg         1.0             iv
# 1  AMX  Amoxicillin      high_dosage          2 g         6.0             iv
#
#   notes        original_txt  eucast_version
# 0   NaN  25-30 mg/kg x 1 iv              13
# 1   NaN          2 g x 6 iv              13

# %%
intrinsic_resistant = pd.read_csv(f"./data/amr-r/intrinsic_resistant.txt", delimiter="\t")
intrinsic_resistant.tail(5)
# Out:
#              microorganism      antibiotic
# 301578  Zongyangia hominis       Aztreonam
# 301579  Zongyangia hominis        Colistin
# 301580  Zongyangia hominis  Nalidixic acid
# 301581  Zongyangia hominis     Polymyxin B
# 301582  Zongyangia hominis      Temocillin

# %%
microorganism_codes = pd.read_csv(f"./data/amr-r/microorganisms.codes.txt", delimiter="\t")
microorganism_codes.tail(4)
# Out:
#         code              mo
# 4967     YZG  F_MYRZY_GLLR-C
# 4968     YZH    F_MYRZY_CRPP
# 4969     ZYM        B_PRPNSP
# 4970  ZYMSPP        B_PRPNSP

# %%
microorganism_groups = pd.read_csv(f"./data/amr-r/microorganisms.groups.txt", delimiter="\t")
microorganism_groups.tail(5)
# Out:
#            mo_group            mo                        mo_group_name  \
# 516  B_YERSN_PSDT-C  B_YERSN_PSDT  Yersinia pseudotuberculosis complex
# 517  B_YERSN_PSDT-C  B_YERSN_PSTS  Yersinia pseudotuberculosis complex
# 518  B_YERSN_PSDT-C  B_YERSN_PSDT  Yersinia pseudotuberculosis complex
# 519  B_YERSN_PSDT-C  B_YERSN_SMLS  Yersinia pseudotuberculosis complex
# 520  B_YERSN_PSDT-C  B_YERSN_WTRS  Yersinia pseudotuberculosis complex
#
#                                             mo_name
# 516                     Yersinia pseudotuberculosis
# 517              Yersinia pseudotuberculosis pestis
# 518  Yersinia pseudotuberculosis pseudotuberculosis
# 519                                Yersinia similis
# 520                              Yersinia wautersii

# %%
microorganisms = pd.read_csv(f"./data/amr-r/microorganisms.txt", delimiter="\t")
microorganisms.head(5)
# Out:
#             mo                            fullname   status   kingdom  \
# 0      B_GRAMN            (unknown Gram-negatives)  unknown  Bacteria
# 1      B_GRAMP            (unknown Gram-positives)  unknown  Bacteria
# 2  B_ANAER-NEG  (unknown anaerobic Gram-negatives)  unknown  Bacteria
# 3  B_ANAER-POS  (unknown anaerobic Gram-positives)  unknown  Bacteria
# 4      B_ANAER        (unknown anaerobic bacteria)  unknown  Bacteria
#
#              phylum            class            order            family  \
# 0  (unknown phylum)  (unknown class)  (unknown order)  (unknown family)
# 1  (unknown phylum)  (unknown class)  (unknown order)  (unknown family)
# 2  (unknown phylum)  (unknown class)  (unknown order)  (unknown family)
# 3  (unknown phylum)  (unknown class)  (unknown order)  (unknown family)
# 4  (unknown phylum)  (unknown class)  (unknown order)  (unknown family)
#
#              genus            species  ... lpsn_parent lpsn_renamed_to  \
# ...

# %%
loinc = pd.read_csv(f"./data/amr-r/Loinc.csv", delimiter=",")
# Out:
# /tmp/ipykernel_98024/1066246570.py:1: DtypeWarning: Columns (8,15,16,17,22,36,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   loinc = pd.read_csv(f"./data/amr-r/Loinc.csv", delimiter=",")

# %%
loinc.head(5)
# Out:
#   LOINC_NUM                                          COMPONENT PROPERTY  \
# 0  100000-9  Health informatics pioneer and the father of L...       Hx
# 1  100001-7  Health informatics pioneer and cofounder of LOINC       Hx
# 2  100002-5                        Specimen care is maintained     Find
# 3  100003-3   Team communication is maintained throughout care     Find
# 4  100004-1  Demonstrates knowledge of the expected psychos...     Find
#
#   TIME_ASPCT    SYSTEM SCALE_TYP METHOD_TYP        CLASS VersionLastChanged  \
# 0         Pt  ^Patient       Nar        NaN       H&P.HX               2.74
# 1         Pt  ^Patient       Nar        NaN       H&P.HX               2.74
# 2         Pt  ^Patient       Ord        NaN  SURVEY.PNDS               2.72
# 3         Pt  ^Patient       Ord        NaN  SURVEY.PNDS               2.72
# 4         Pt  ^Patient       Ord        NaN  SURVEY.PNDS               2.72
#
#   CHNG_TYPE  ... COMMON_ORDER_RANK COMMON_SI_TEST_RANK  \
# ...
